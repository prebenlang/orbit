# %%
#Load libraries
from math import sqrt
import matplotlib.pyplot as plt

#Global Variables
G = 6.67430e-11 #Gravitational constant

#Simulation variables
scale = 60 #seconds
iterations = 3153600 #3153600


#Define bodies

#Sun
sun_mass = 1989000000000000000000000000000 #kg
sun_pos = [0,-0]
sun_vx = -0.089 # m/s #-0.089
sun_vy = 0 # m/s
sun_x_positions = [] #Variables for MatPlotLib
sun_y_positions = [] #Variables for MatPlotLib

# Mercury
# Venus

#Earth
earth_mass = 5973000000000000000000000 #kg
earth_r = 149600000000 #meter from Sun
earth_pos = [0,earth_r]
earth_vx = 29789 # m/s
earth_vy = 0 # m/s
earth_x_positions = [] #Variables for MatPlotLib
earth_y_positions = [] #Variables for MatPlotLib

# Moon
# Mars
# Jupiter
# Saturn
# Uranus
# Neptune
# Pluto
